# %% [markdown]
# # Modelo 4: Janela Móvel

# %% [markdown]
# # Importação de Variáveis e Indicadores

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

btc = pd.read_excel("../wrangled_data/serie_bitcoin.xlsx", index_col = "Data")
variaveis = pd.read_excel("../wrangled_data/variaveis.xlsx", index_col = "Data")

stop_fixo = pd.read_excel("../wrangled_data/stop_fixo.xlsx", index_col = "Data")
stop_vol = pd.read_excel("../wrangled_data/stop_vol.xlsx", index_col = "Data")

# %% [markdown]
# # DF original

# %%
df_var = variaveis.join(stop_fixo)
df_var.drop(["Retorno", "Alvo_Contínuo", "Stop_Long", "Stop_Short"], axis = 1, inplace = True)
df_var.head()
# Out:
#             AN_INFLATION  END_ATIVOS  HASH_RATE30  FEE_MEAN     MMULT  \
# Data
# 2011-02-01     -0.036790    1.346414     0.012031  0.392474  3.962088
# 2011-02-02     -0.038023    1.361285     0.010910  0.238807  3.934975
# 2011-02-03      0.011130    1.342658     0.013371  0.104872  3.764052
# 2011-02-04      0.210286    1.355250     0.018983  0.168706  4.298699
# 2011-02-07      0.144713    1.340026     0.017436  0.149473  4.426032
#
#              MRGO140    MRGO28      MVRV    MVRV_Z  THERMOCAP  ...      PROP  \
# Data                                                           ...
# 2011-02-01  4.259223  4.472763  5.023446  5.562989   0.000001  ...  0.578913
# 2011-02-02  3.738760  4.252111  4.955148  5.412498   0.000001  ...  0.085702
# 2011-02-03  3.166427  3.801977  4.686634  5.053846   0.000001  ... -0.295465
# 2011-02-04  3.752805  4.627094  5.360298  5.914965   0.000002  ...  0.508096
# 2011-02-07  3.034375  4.279002  5.252936  5.725800   0.000002  ... -0.161603
#
#             D0  D1  D2  D3       Z30       RSL  TEND_ALTA  TEND_BAIXA  \
# Data
# 2011-02-01   1   1   1   0  1.644952  0.496305          1           0
# 2011-02-02   1   1   1   1  1.660428  0.431013          1           0
# 2011-02-03   0   1   1   1  1.677207  0.318935          1           0
# 2011-02-04   1   0   1   1  1.691116  0.427581          1           0
# 2011-02-07   0   0   1   1  1.730407  0.254542          1           0
#
#             Alvo_Binário
# Data
# 2011-02-01             1
# 2011-02-02             0
# 2011-02-03             1
# 2011-02-04             1
# 2011-02-07             1
#
# [5 rows x 33 columns]

# %% [markdown]
# # Modelagem

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, auc, RocCurveDisplay
from sklearn.model_selection import GridSearchCV

# %%
n = 100
datas = list(df.index)
n_datas = len(datas)

treinos = treino(df_var)

def previsao(df):
    trains = []
    tests = []
    for i in range(len(datas) - n):
        trains.append(df.iloc[i:i+n, :])
        tests.append(df.iloc[i+n, :])
    
    
    retornos = []
    for train, test in trains, tests:
        data_obs = test.index
        X_train = train.drop("Alvo")
        y_train = train["Alvo"]
        X_test = test.drop("Alvo")
        y_test = test["Alvo"]

        modelo = MLPClassifier(random_state = 42, solver = "sgd", activation = "tanh")
        modelo.fit(X_train, y_train)
        y_pred = modelo.predict(X_test, y_test)

        bt = pd.DataFrame()
        bt["y_t"] = y_test
        bt["y_p"] = pd.Series(y_pred)


        ret = np.where(bt["y_p"] == 1, bt["Alvo_Continuo"], -bt["Alvo_Continuo"])
        print(ret)
        retornos.append(ret)
        
    return ret

# %%
previsao(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\BRUNOM~1\AppData\Local\Temp/ipykernel_7068/719660698.py in <module>
# ----> 1 previsao(df)
#
# C:\Users\BRUNOM~1\AppData\Local\Temp/ipykernel_7068/113118364.py in previsao(df)
#       7
#       8     retornos = []
# ----> 9     for train, test in trains, tests:
#      10         data_obs = test.index
#      11         X_train = train.drop("Alvo")
#
# ValueError: too many values to unpack (expected 2)
